# %% [markdown]
# # Running and Observing Agents

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.messages import TextMessage
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
model_client = OpenAIChatCompletionClient(model='gpt-4o', api_key=api_key)

# %%
async def web_search(query: str) -> str:
    """Find information on the web"""
    return "The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. "

# %%
agent = AssistantAgent(
    name='assistant',
    model_client=model_client,
    tools=[web_search],
    system_message='Use Tools to solve tasks'
)

# %%
result = await agent.run(task='Find information about Labrador Retriever')
print(result.messages[-1].content)
# Out:
# The Labrador Retriever or simply Labrador is a British breed of retriever gun dog.

# %% [markdown]
# ### On_message() method

# %%
from autogen_core import CancellationToken

async def assistant_run()-> None:
    response = await agent.on_messages(
        messages= [TextMessage(content='Find information about Labrador Retriever',source='User')],
        cancellation_token=CancellationToken()
    )

    print(response.inner_messages)
    print('\n\n\n\n')
    print(response.chat_message)

await assistant_run()
# Out:
# []
#
#
#
#
#
# id='fb9dc4e9-a26c-4054-9a36-1a6eaff4942c' source='assistant' models_usage=RequestUsage(prompt_tokens=115, completion_tokens=341) metadata={} created_at=datetime.datetime(2026, 1, 20, 8, 35, 0, 629141, tzinfo=datetime.timezone.utc) content='The Labrador Retriever, often known simply as a Labrador, is a highly popular breed of retriever gun dog that originated in the United Kingdom. Renowned for its friendly demeanor, intelligence, and versatility, the Labrador Retriever is a beloved family pet and working dog.\n\nHere are some key characteristics of the Labrador Retriever:\n\n1. **Temperament**: Labradors are known for being friendly, outgoing, and even-tempered. They get along well with people and other animals, making them an excellent family dog.\n\n2. **Intelligence**: This breed is highly intelligent and eager to please, which makes them highly trainable. They excel in various roles, from assistance and therapy dogs to active roles in search and rescue.\n\n3. **Physical Characteristics**: Labradors are medium-to-large-sized dogs, with a strong, athletic build. They have a distinctive short, dense, and water-resistant coat, which comes in three main colors: black, yellow, and chocolate.\n\n4. **Activity Level**: They are very active and require regular exercise to maintain their physical and mental health. Activities like fetch, swimming, and long walks are ideal for them.\n\n5. **Life Span**: The average lifespan of a Labrador Retriever is around 10-12 years.\n\n6. **Health**: While generally healthy, Labradors can be prone to certain genetic health issues, such as hip and elbow dysplasia, eye conditions, and obesity. Regular veterinary checkups and a balanced diet help mitigate these risks.\n\nTheir adaptability and gentle nature make Labrador Retrievers one of the most popular dog breeds worldwide. Whether as a companion, working dog, or performance animal, they bring joy and utility to many homes.' type='TextMessage'

# %%
from autogen_core import CancellationToken

async def assistant_run()-> None:
    response = await agent.on_messages(
        messages= [TextMessage(content='Find information about Labrador Retriever via the tool',source='User')],
        cancellation_token=CancellationToken()
    )

    print(response.inner_messages)
    print('\n\n\n\n')
    print(response.chat_message)

await assistant_run()
# Out:
# [ToolCallRequestEvent(id='6a1815ba-3311-4e50-bbcc-65801516a040', source='assistant', models_usage=RequestUsage(prompt_tokens=473, completion_tokens=19), metadata={}, created_at=datetime.datetime(2026, 1, 20, 8, 35, 1, 550487, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_r2WgGzqOxupOX4BwBDcrWU6l', arguments='{"query":"Labrador Retriever breed information"}', name='web_search')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='fbbb7513-e086-4bd8-a0d6-f19bc494c925', source='assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 1, 20, 8, 35, 1, 550487, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ', name='web_search', call_id='call_r2WgGzqOxupOX4BwBDcrWU6l', is_error=False)], type='ToolCallExecutionEvent')]
#
#
#
#
#
# id='390f0aa3-2e42-42b8-9384-d9bfdc106faa' source='assistant' models_usage=None metadata={} created_at=datetime.datetime(2026, 1, 20, 8, 35, 1, 550487, tzinfo=datetime.timezone.utc) content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ' type='ToolCallSummaryMessage' tool_calls=[FunctionCall(id='call_r2WgGzqOxupOX4BwBDcrWU6l', arguments='{"query":"Labrador Retriever breed information"}', name='web_search')] results=[FunctionExecutionResult(content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ', name='web_search', call_id='call_r2WgGzqOxupOX4BwBDcrWU6l', is_error=False)]

# %% [markdown]
# ### Streaming Messages
#
# #### on_messages_stream()

# %%
from autogen_agentchat.ui import Console


async def assistant_run_stream() -> None:

    await Console(
        agent.on_messages_stream(
        messages= [TextMessage(content='Find information about Labrador Retriever via the tool',source='User')],
        cancellation_token=CancellationToken()
    ),
    output_stats=True # Enable stats Printing
    )


await assistant_run_stream()
# Out:
# ---------- ToolCallRequestEvent (assistant) ----------
# [FunctionCall(id='call_6WHixp8oIEAfwOQBb9Kxz5R8', arguments='{"query":"Labrador Retriever dog breed details"}', name='web_search')]
# [Prompt tokens: 590, Completion tokens: 20]
# ---------- ToolCallExecutionEvent (assistant) ----------
# [FunctionExecutionResult(content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ', name='web_search', call_id='call_6WHixp8oIEAfwOQBb9Kxz5R8', is_error=False)]
# ---------- assistant ----------
# The Labrador Retriever or simply Labrador is a British breed of retriever gun dog.
# ---------- Summary ----------
# Number of inner messages: 2
# Total prompt tokens: 590
# Total completion tokens: 20
# Duration: 1.82 seconds
