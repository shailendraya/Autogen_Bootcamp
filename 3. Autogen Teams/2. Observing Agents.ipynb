# %% [markdown]
# # Observe a running team in Autogen

# %%
import asyncio
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
model_client = OpenAIChatCompletionClient(model='gpt-4o', api_key=api_key)

# %%
from autogen_agentchat.agents import AssistantAgent
plot_agent = AssistantAgent(
    name = 'plot_writer',
    model_client=model_client,
    system_message="You create engaging plots for stories. Focus on the Knight's journey.compelte it in 10 words"
)

character_agent = AssistantAgent(
    name = 'character_writer',
    model_client=model_client,
    system_message="You develop characters. Describe the knight and the dragon in detail, including their motivations and backgrounds.compelte it in 10 words"
)

ending_agent = AssistantAgent(
    name = 'ending_writer',
    model_client=model_client,
    system_message="You wrute engaging endings. conclude the story with a twist. compelte it in 10 words"
)

# %%
from autogen_agentchat.teams import RoundRobinGroupChat

team = RoundRobinGroupChat(
    [plot_agent, character_agent, ending_agent],
    max_turns=3
)

# %%
from autogen_agentchat.base import TaskResult

async for message in team.run_stream(task = 'Write a poem on the Spring Season'):
    if isinstance(message,TaskResult):
        print(f"Stop Reason: {message.stop_reason}")
    else:
        print((message))
# Out:
# id='f667c1c9-2ec9-46b5-b6a5-77156fd8709e' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 1, 31, 4, 34, 38, 647921, tzinfo=datetime.timezone.utc) content='Write a poem on the Spring Season' type='TextMessage'
# id='80530f54-1ff0-410b-9e23-b24c2ad37b5b' source='plot_writer' models_usage=RequestUsage(prompt_tokens=39, completion_tokens=16) metadata={} created_at=datetime.datetime(2026, 1, 31, 4, 34, 41, 782235, tzinfo=datetime.timezone.utc) content="Blossoms bloom, nature's embrace, vibrant hues fill spring's grace." type='TextMessage'
# id='bc160a77-6feb-4233-9771-4a3ee15076fe' source='character_writer' models_usage=RequestUsage(prompt_tokens=67, completion_tokens=225) metadata={} created_at=datetime.datetime(2026, 1, 31, 4, 34, 47, 143912, tzinfo=datetime.timezone.utc) content="**The Knight:**\nA battle-hardened warrior, Sir Alaric possesses a strong sense of duty and honor. Raised from a young age in a noble family, he was taught the values of courage, chivalry, and loyalty. Driven by a quest for redemption after losing his kingdom in a fierce battle, he now roams the land, seeking to restore his family's honor and protect the innocent. His armor is adorned with the emblem of a phoenix, symbolizing rebirth and resilience. Alaric's determination is fueled by a promise made to his fallen comrades to never let tyranny prevail.\n\n**The Dragon:**\nAncient and wise, Zephyr is a dragon that has witnessed centuries pass. Once a guardian of the realm, Zephyr retreated to the mountains after humans encroached upon the dragon lands. Driven by a desire to protect the balance of nature, Zephyr avoids conflict with humans but will fiercely defend the forest realm. His shimmering emerald scales are a testament to his mystical lineage. Zephyr's motivation lies in preserving the old magic of the world, ensuring harmony between humans and nature." type='TextMessage'
# id='2b240069-6ac2-4bbb-b4cc-47862147b9ea' source='ending_writer' models_usage=RequestUsage(prompt_tokens=294, completion_tokens=13) metadata={} created_at=datetime.datetime(2026, 1, 31, 4, 34, 48, 130033, tzinfo=datetime.timezone.utc) content='The knight removes helmet; face revealed as dragon’s human guise.' type='TextMessage'
# Stop Reason: Maximum number of turns 3 reached.

# %%
from autogen_agentchat.ui import Console

await Console(team.run_stream(task = 'Write a poem on the Spring Season'))
# Out:
# ---------- TextMessage (user) ----------
# Write a poem on the Spring Season
# ---------- TextMessage (character_writer) ----------
# In springtime's gentle, warm embrace,
# Earth awakens with tender grace.
# Blossoms burst in vibrant hue,
# Nature's palette, fresh and new.
#
# Whispering winds dance through trees,
# Carrying scents of blooming seas.
# Birds return with joyful song,
# In harmony, they sing along.
#
# Rivers thaw, begin to flow,
# Reflecting skies of azure glow.
# Life renews, in every nook,
# Spring writes its tale in nature's book.
# TaskResult(messages=[TextMessage(id='fbbe3c6b-0744-43d1-b04a-c39c78bbbbd3', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 1, 31, 4, 39, 13, 129647, tzinfo=datetime.timezone.utc), content='Write a poem on the Spring Season', type='TextMessage'), TextMessage(id='434ec9d4-70fb-47ae-8fef-a75b35c620d8', source='character_writer', models_usage=RequestUsage(prompt_tokens=340, completion_tokens=105), metadata={}, created_at=datetime.datetime(2026, 1, 31, 4, 39, 16, 985339, tzinfo=datetime.timezone.utc), content="In springtime's gentle, warm embrace,  \nEarth awakens with tender grace.  \nBlossoms burst in vibrant hue,  \nNature's palette, fresh and new.  \n\nWhispering winds dance through trees,  \nCarrying scents of blooming seas.  \nBirds return with joyful song,  \nIn harmony, they sing along.  \n\nRivers thaw, begin to flow,  \nReflecting skies of azure glow.  \nLife renews, in every nook,  \nSpring writes its tale in nature's book.  ", type='TextMessage')], stop_reason='The group chat is stopped.')
